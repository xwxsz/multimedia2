# %% [markdown]
# # ЛР8 Обнаружение и распознавание объектов

# %% [markdown]
# # Бейзлайн

# %% [markdown]
# #### Импорт библиотек

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from ultralytics import YOLO
# %matplotlib inline

# %% [markdown]
# #### Обучение модели

# %%
model = YOLO('yolov8s.pt')

model.train(
    data='set/coco128.yaml', 
    epochs=20,
    imgsz=640,
    batch=8,
    device='cpu',
    max_det=50, 
)
# Out:
# Ultralytics 8.3.140 🚀 Python-3.12.2 torch-2.7.0 CPU (Apple M3)
# ...

# %% [markdown]
# #### Метрики

# %%
metrics = model.val()
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
# Out:
# Ultralytics 8.3.140 🚀 Python-3.12.2 torch-2.7.0 CPU (Apple M3)
# Model summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2796.5±1196.2 MB/s, size: 70.9 KB)
# val: Scanning /Users/xwxsz/Desktop/set/coco128/labels/train2017.cache... 126 ima
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        128        929       0.87      0.761      0.833      0.676
#                 person         61        254      0.959      0.638       0.86      0.681
#                bicycle          3          6          1      0.741      0.843      0.486
#                    car         12         46      0.943      0.239      0.566      0.292
#             motorcycle          4          5      0.891          1      0.995      0.865
#               airplane          5          6      0.937          1      0.995       0.92
# ...

# %% [markdown]
# #### Вывод изображений

# %%
image_dir = 'set/coco128/images/train2017'
image_files = random.sample(os.listdir(image_dir), 3)

for img_name in image_files:
    img_path = os.path.join(image_dir, img_name)

    results = model(img_path)

    img_plot = results[0].plot() 

    plt.imshow(img_plot)
    plt.axis('off')
    plt.title(f"Prediction for {img_name}")
    plt.show()
# Out:
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000597.jpg: 256x640 7 elephants, 42.0ms
# Speed: 0.5ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 640)
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000472.jpg: 256x640 1 airplane, 41.7ms
# Speed: 0.4ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 640)
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000636.jpg: 640x480 1 toilet, 79.0ms
# Speed: 0.7ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# # Улучшенный бейзлайн

# %% [markdown]
# #### Обучение модели

# %%
model = YOLO("yolov8s.pt")

model.train(
    data="set/coco128.yaml",   
    epochs=20,                 
    imgsz=640,                 
    device="cpu",
    max_det=50,

    optimizer="SGD",
    lr0=0.01,                  
    lrf=0.01,                  
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=1,
    warmup_momentum=0.8,

    # Коэффициенты потерь
    box=0.05,
    cls=0.5,
    dfl=1.0,

    # Расширенные аугментации
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.3,
    translate=0.1,
    scale=0.9,
    shear=0.2,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.2,
    copy_paste=0.1,

    cos_lr=True,
    patience=10,              

    batch=8
)
# Out:
# Ultralytics 8.3.140 🚀 Python-3.12.2 torch-2.7.0 CPU (Apple M3)
# ...

# %% [markdown]
# #### Метрики

# %%
metrics = model.val()
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
# Out:
# Ultralytics 8.3.140 🚀 Python-3.12.2 torch-2.7.0 CPU (Apple M3)
# Model summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1777.0±658.2 MB/s, size: 47.5 KB)
# val: Scanning /Users/xwxsz/Desktop/set/coco128/labels/train2017.cache... 126 ima
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        128        929       0.84      0.731      0.808      0.621
#                 person         61        254      0.954      0.647      0.838      0.629
#                bicycle          3          6          1       0.32      0.603      0.335
#                    car         12         46      0.944      0.366      0.617       0.31
#             motorcycle          4          5      0.774          1      0.995      0.734
#               airplane          5          6      0.937          1      0.995      0.899
# ...

# %% [markdown]
# #### Вывод изображений

# %%
image_dir = 'set/coco128/images/train2017'
image_files = random.sample(os.listdir(image_dir), 3)

for img_name in image_files:
    img_path = os.path.join(image_dir, img_name)
    results = model(img_path)
    img_plot = results[0].plot()
    
    plt.imshow(img_plot)
    plt.axis('off')
    plt.title(f"Prediction for {img_name}")
    plt.show()
# Out:
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000626.jpg: 480x640 2 clocks, 66.6ms
# Speed: 0.6ms preprocess, 66.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000446.jpg: 640x480 1 person, 1 couch, 3 potted plants, 1 remote, 17 books, 66.9ms
# Speed: 0.5ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# image 1/1 /Users/xwxsz/Desktop/set/coco128/images/train2017/000000000581.jpg: 640x608 1 dog, 89.0ms
# Speed: 1.2ms preprocess, 89.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
